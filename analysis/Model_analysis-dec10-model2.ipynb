# %% [raw]
# An analysis of the output model and its performance.

# %%
import sys
sys.path.append("..")

# %%
from config import *

# %%
TPU_MODE=False
SHUFFLE=False

# %%
import ipywidgets as widgets
import datetime
import tensorflow as tf

import dataset_functions
from models.six_stage_linear_model import ModelMaker
import callbacks
import dataset_builder
import load_weights

# %%
import matplotlib.pyplot as plt
import visualizations as v

# %%
tfrecord_files_train,tfrecord_files_val=dataset_builder.get_tfrecord_filenames()
print("Found the following val TFrecords:\n","\n".join(tfrecord_files_val))

print("Building training dataset")
dst=dataset_builder.build_training_ds(tfrecord_files_train)
print("Training dataset shape:",dst)
print("Building validation dataset")
dsv=dataset_builder.build_validation_ds(tfrecord_files_val)
print("Validation dataset shape:",dsv)
# Out:
# Retrieving TFrecords in TPU_mode
# Found the following val TFrecords:
#  gs://datasets_bucket_a/validation-001.tfrecords
# gs://datasets_bucket_a/validation-002.tfrecords
# gs://datasets_bucket_a/validation-003.tfrecords
# Building training dataset
# Training dataset shape: <PrefetchDataset shapes: (((None, 368, 368, 3), (None, 46, 46, 1)), ((None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 19), (None, 46, 46, 19))), types: ((tf.float32, tf.float32), (tf.float32, tf.float32, tf.float32, tf.float32, tf.float32, tf.float32))>
# Building validation dataset
# Validation dataset shape: <BatchDataset shapes: (((None, 368, 368, 3), (None, 46, 46, 1)), ((None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 35), (None, 46, 46, 19), (None, 46, 46, 19))), types: ((tf.float32, tf.float32), (tf.float32, tf.float32, tf.float32, tf.float32, tf.float32, tf.float32))>

# %%
checkpoint,starting_epoch=load_weights.checkpoints_prompt()
# Out:
# Found these checkpoints
# 0.Dont load checkpoint
# 1 .gs://dl_training_results/checkpoints//08Sun1219-0208/Checkpoint-E0001.ckpt
# 2 .gs://dl_training_results/checkpoints//08Sun1219-0219/Checkpoint-E0001.ckpt
# 3 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0001.ckpt
# 4 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0002.ckpt
# 5 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0003.ckpt
# 6 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0004.ckpt
# 7 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0005.ckpt
# 8 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0006.ckpt
# 9 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0007.ckpt
# 10 .gs://dl_training_results/checkpoints//08Sun1219-0245/Checkpoint-E0008.ckpt
# 11 .gs://dl_training_results/checkpoints//08Sun1219-1224/Checkpoint-E0001.ckpt
# 12 .gs://dl_training_results/checkpoints//08Sun1219-1224/Checkpoint-E0002.ckpt
# 13 .gs://dl_training_results/checkpoints//08Sun1219-1224/Checkpoint-E0003.ckpt
# 14 .gs://dl_training_results/checkpoints//08Sun1219-1249/Checkpoint-E0004.ckpt
# 15 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0001.ckpt
# 16 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0002.ckpt
# 17 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0003.ckpt
# 18 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0004.ckpt
# 19 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0005.ckpt
# 20 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0006.ckpt
# 21 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0007.ckpt
# 22 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0008.ckpt
# 23 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0009.ckpt
# 24 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0010.ckpt
# 25 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0011.ckpt
# 26 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0012.ckpt
# 27 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0013.ckpt
# 28 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0014.ckpt
# 29 .gs://dl_training_results/checkpoints//08Sun1219-1300/Checkpoint-E0015.ckpt
# 30 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0010/-E0001.ckpt
# 31 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0025/-E0001.ckpt
# 32 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0025/-E0002.ckpt
# 33 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0025/-E0003.ckpt
# 34 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0110/-E0001.ckpt
# 35 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0110/-E0002.ckpt
# 36 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0126/-E0001.ckpt
# 37 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0126/-E0002.ckpt
# 38 .gs://dl_training_results/checkpoints//Second_model_l1loss09Mon1219-0126/-E0003.ckpt
# 39 .gs://dl_training_results/checkpoints/02Mon1219-1345/Checkpoint-E0001.ckpt
# 40 .gs://dl_training_results/checkpoints/02Mon1219-1348/Checkpoint-E0001.ckpt
# 41 .gs://dl_training_results/checkpoints/02Mon1219-1404/Checkpoint-E0001.ckpt
# 42 .gs://dl_training_results/checkpoints/02Mon1219-1404/Checkpoint-E0002.ckpt
# 43 .gs://dl_training_results/checkpoints/02Mon1219-1404/Checkpoint-E0003.ckpt
# 44 .gs://dl_training_results/checkpoints/02Mon1219-1434/Checkpoint-E0001.ckpt
# 45 .gs://dl_training_results/checkpoints/02Mon1219-1434/Checkpoint-E0002.ckpt
# 46 .gs://dl_training_results/checkpoints/02Mon1219-1434/Checkpoint-E0003.ckpt
# 47 .gs://dl_training_results/checkpoints/02Mon1219-1434/Checkpoint-E0004.ckpt
# 48 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0001.ckpt
# 49 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0002.ckpt
# 50 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0003.ckpt
# 51 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0004.ckpt
# 52 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0005.ckpt
# 53 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0006.ckpt
# 54 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0007.ckpt
# 55 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0008.ckpt
# 56 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0009.ckpt
# 57 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0010.ckpt
# 58 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0011.ckpt
# 59 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0012.ckpt
# 60 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0013.ckpt
# 61 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0014.ckpt
# 62 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0015.ckpt
# 63 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0016.ckpt
# 64 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0017.ckpt
# 65 .gs://dl_training_results/checkpoints/02Mon1219-1455/Checkpoint-E0018.ckpt
# Please select checkpoint, or 0 to continue without loading38

# %%
model_maker=ModelMaker() #must be outside scope to keep the graph clean
tf.keras.backend.clear_session() #to clean to backaend from the imported model

train_model,test_model=model_maker.create_models()
if (checkpoint):
    train_model.load_weights(checkpoint)

# %%
model_name="Second_model_l1loss_bn"

# %%
model_path=MODELS_PATH+model_name+"-"+datetime.datetime.now().strftime("%d(%a)%m%y-%H%M")
tf.keras.models.save_model(train_model,model_path)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1788: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: gs://dl_training_results/models/Second_model_l1loss_bn-09(Mon)1219-1642/assets

# %% [markdown]
# ---
# ## Dataset input (truth)

# %%
#service functions
def remove_mask(inp):
    return inp[...,:-1]
def decmopose_ds_elem(st,idx):
    img=st[0][0][idx:idx+1].numpy()
    paf=st[1][3][idx:idx+1].numpy()
    kpt=st[1][5][idx:idx+1].numpy()
    
    paf=remove_mask(paf)
    kpt=remove_mask(kpt)
    return img,(paf,),(kpt,)

def get_train_model_output(model,st,idx):
    
    img=st[0][0][idx:idx+1].numpy() #get img from sample tensor
    empty_mask=np.zeros((1,46,46,1)) #generate mask
    inputs=(img,empty_mask) #bundle
    
    pred_t=train_model.predict(inputs) #actual prediction
    
    paf0=remove_mask(pred_t[0])
    paf1=remove_mask(pred_t[1])
    paf2=remove_mask(pred_t[2])
    paf3=remove_mask(pred_t[3])
    kpt0=remove_mask(pred_t[4])
    kpt1=remove_mask(pred_t[5])
    
    return img,(paf0,paf1,paf2,paf3),(kpt0,kpt1)

def extract_single_paf(paf,idx):
    ldim=int(paf.shape[-1]/2)
    return np.stack([paf[...,idx],paf[...,idx+ldim]],axis=-1)

# %%
st=next(iter(dst))
idx=0

# %%
joint_num=-1 #-1 to show all, otherwise joint num to isolate

# %%
idx=idx+1

# %%
img,(paf,),(kpt,)=decmopose_ds_elem(st,idx)
if joint_num>0:
    paf=extract_single_paf(paf,joint_num)
v.show_img_pafs_kpts(img,paf,kpt,figure_size=30)

# %% [markdown]
# ---
# ## Model prediction

# %%
img,(paf0,paf1,paf2,paf3),(kpt0,kpt1)=get_train_model_output(train_model,st,idx)
paf=paf3 #select the outoput to check
kpt=kpt1
if joint_num>0:
    paf=extract_single_paf(paf,joint_num)
v.show_img_pafs_kpts(img,paf,kpt,figure_size=30)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(pred_paf2[0,...,0+17])
plt.colorbar()

# %% [raw]
# Observations
# -the model is learning, at least the first stages do, and do well
# -but the model is doing poorly in the PAF angles, it seems to snap to the nearest orthogonal direction
# -The kpts, being located after a failed paf stage dont learn well
# --the recognise faces,eyes and ears, but not limbs
#
# Ideas
# -The angle snapping might be due to the L2 loss, small angles don't look different than the background, and the neuron doesn't learn.
# -one option is to change to L1 Loss
# -the other is to add a mask of imprtance to the areas where there is a PAF
# --ie, punish false negatives more than false positives,
# -- maybe balance the mask at 50/50
